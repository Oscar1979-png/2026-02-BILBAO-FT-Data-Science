# %% [markdown]
# ## Ejercicio descargas

# %% [markdown]
# Python es un lenguaje de propósito general, por lo que podemos desarrollar otros programas,
# aparte de ciencia de datos, que nos permitan montar dashboards, crear APIs o automatizar
# procesos. En este caso vas a automatizar un proceso, en el que tendrás que desarrollar un
# script que ordene todos los archivos de una carpeta, dependiendo de la extensión de los
# mismos.
#
#
# El objetivo es ordenar la típica carpeta de cajón desastre donde se nos acumulan archivos de
# todos los formatos como: imágenes, words, presentaciones, excels, ejecutables, zips, etc... Y
# que no vamos a ir viendo archivo a archivo, ordenándolos.... La solución suele ser eliminarlo
# todo. Vamos a intentar no tener que llegar a eso, ordenando los ficheros automáticamente en
# carpetas y revisar las que nos interesen. La típica carpeta donde aplicaríamos este programa es
# la de “Descargas”, donde se suelen acumular muchos archivos temporales.
#
#
# Por tanto, **el programa tiene que guardar los archivos de la carpeta “Descargas” (o cualquier
# otra donde acumules mucho archivo temporal) en los siguientes directorios dentro de la
# propia carpeta “Descargas”**:
# - Imagenes
# - Documentos
# - Software
# - Otros
#
# Cada vez que ejecutes el script, automáticamente se ordenarán todos los archivos en sus
# correspondientes carpetas.

# %%
doc_types = ('.doc', '.docx', '.txt', '.pdf', '.xls', '.ppt', '.xlsx', '.pptx')
img_types = ('.jpg', '.jpeg', '.png', '.svg', '.gif')
software_types = ('.exe', '.py','.ipynb')

# %% [markdown]
# ### 1. Crea un un programa con el flujo principal y encapsúlalo en funciones.

# %%
import os
import shutil

# %%
os.getcwd()
# Out:
# 'c:\\Users\\oscar\\Documents\\DATASCIENCEOF\\2026-02-BILBAO-FT-Data-Science\\2-Data_Analysis\\3-Sources\\Archivos\\Practica'

# %%
os.listdir()
# Out:
# ['Ejercicio_descargas.ipynb']

# %%
ruta = os.path.join(os.getcwd(), "Carpeta_backup_descargas")
ruta
# Out:
# 'c:\\Users\\oscar\\Documents\\DATASCIENCEOF\\2026-02-BILBAO-FT-Data-Science\\2-Data_Analysis\\3-Sources\\Archivos\\Practica\\Carpeta_backup_descargas'

# %%
os.listdir(ruta)
# Out:
# ['1_Intro_Pandas.ipynb',
#  '2-Estadística_descriptiva.ipynb',
#  'actividades-participacion-2024-2025.csv',
#  'Alcohol_Consumption.ipynb',
#  'Alcohol_Consumption_OFG.ipynb',
#  'Anexo 4 - Tests de dependencia entre variables.ipynb',
#  'API_data.ipynb',
#  'archive.zip',
#  'banderas-zierbena-2022.csv',
#  'Basics_I.ipynb',
#  'Basics_II.ipynb',
#  'birras_repaso (1).ipynb',
#  'birras_repaso.ipynb',
#  'Chipotle_SOL_I (1).ipynb',
#  'Chipotle_SOL_I.ipynb',
#  'ChromeSetup.exe',
#  'Colecciones.ipynb',
#  'ejercicios.png',
#  'Ejerciciosmarkdown.ipynb',
#  'Ejerciciosmarkdown_OFG (1).ipynb',
#  'Ejerciciosmarkdown_OFG.ipynb',
#  'Ejercicios_Basics_II.ipynb',
#  'Ejercicios_Colecciones.ipynb',
#  'Ejercicios_Colecciones_Extra.ipynb',
#  'Ejercicios_Flujos_Control.ipynb',
#  'Ejercicios_Numpy_I.ipynb',
#  'Ejercicios_Numpy_II.ipynb',
#  'Euro12.ipynb',
#  'Euro12_OFG.ipynb',
#  'FAC 80 Ganakogorta MINAWORK.pdf',
#  'Fictional Army.ipynb',
#  'Fictitious_names.ipynb',
#  'FreeFileSync_14.8_Windows_Setup (1).exe',
#  'FreeFileSync_14.8_Windows_Setup.exe',
#  'Git-2.53.0-64-bit.exe',
#  'GitHubDesktopSetup-x64 (1).exe',
#  'GitHubDesktopSetup-x64 (1).msi',
#  'GitHubDesktopSetup-x64 (2).exe',
#  'GitHubDesktopSetup-x64 (2).msi',
#  'GitHubDesktopSetup-x64 (3).exe',
#  'GitHubDesktopSetup-x64 (4).exe',
#  'GitHubDesktopSetup-x64.exe',
#  'GitHubDesktopSetup-x64.msi',
#  'HLF_OFG.py',
#  'Intro_python.md',
#  'Mi primer notebook.py',
#  'mini_HLF.ipynb',
#  'mini_HLF_OFG.ipynb',
#  'mini_HLF_OFG.ipynb_Notas_Correccion (1).md',
#  'mini_HLF_OFG.ipynb_Notas_Correccion.md',
#  'Occupation.ipynb',
#  'open-meteo-43.25N2.92W14m.csv',
#  'PBIDesktopSetup_x64.exe',
#  'Postman (x64).exe',
#  'python (1).exe',
#  'Python - Web.pdf',
#  'python-3.11.9-amd64 (1).exe',
#  'python-3.11.9-amd64.exe',
#  'python.exe',
#  'Titanic-exercise.ipynb',
#  'Titanic_OFG.ipynb',
#  'VSCodeUserSetup-x64-1.109.5 (1).exe',
#  'VSCodeUserSetup-x64-1.109.5.exe']

# %%
for archivo in os.listdir(ruta):
    print(archivo)
# Out:
# 1_Intro_Pandas.ipynb
# 2-Estadística_descriptiva.ipynb
# actividades-participacion-2024-2025.csv
# Alcohol_Consumption.ipynb
# Alcohol_Consumption_OFG.ipynb
# Anexo 4 - Tests de dependencia entre variables.ipynb
# API_data.ipynb
# archive.zip
# banderas-zierbena-2022.csv
# Basics_I.ipynb
# Basics_II.ipynb
# birras_repaso (1).ipynb
# birras_repaso.ipynb
# Chipotle_SOL_I (1).ipynb
# Chipotle_SOL_I.ipynb
# ChromeSetup.exe
# Colecciones.ipynb
# ejercicios.png
# Ejerciciosmarkdown.ipynb
# Ejerciciosmarkdown_OFG (1).ipynb
# Ejerciciosmarkdown_OFG.ipynb
# Ejercicios_Basics_II.ipynb
# Ejercicios_Colecciones.ipynb
# Ejercicios_Colecciones_Extra.ipynb
# Ejercicios_Flujos_Control.ipynb
# Ejercicios_Numpy_I.ipynb
# Ejercicios_Numpy_II.ipynb
# Euro12.ipynb
# Euro12_OFG.ipynb
# FAC 80 Ganakogorta MINAWORK.pdf
# Fictional Army.ipynb
# Fictitious_names.ipynb
# FreeFileSync_14.8_Windows_Setup (1).exe
# FreeFileSync_14.8_Windows_Setup.exe
# Git-2.53.0-64-bit.exe
# GitHubDesktopSetup-x64 (1).exe
# GitHubDesktopSetup-x64 (1).msi
# GitHubDesktopSetup-x64 (2).exe
# GitHubDesktopSetup-x64 (2).msi
# GitHubDesktopSetup-x64 (3).exe
# GitHubDesktopSetup-x64 (4).exe
# GitHubDesktopSetup-x64.exe
# GitHubDesktopSetup-x64.msi
# HLF_OFG.py
# Intro_python.md
# Mi primer notebook.py
# mini_HLF.ipynb
# mini_HLF_OFG.ipynb
# mini_HLF_OFG.ipynb_Notas_Correccion (1).md
# mini_HLF_OFG.ipynb_Notas_Correccion.md
# Occupation.ipynb
# open-meteo-43.25N2.92W14m.csv
# PBIDesktopSetup_x64.exe
# Postman (x64).exe
# python (1).exe
# Python - Web.pdf
# python-3.11.9-amd64 (1).exe
# python-3.11.9-amd64.exe
# python.exe
# Titanic-exercise.ipynb
# Titanic_OFG.ipynb
# VSCodeUserSetup-x64-1.109.5 (1).exe
# VSCodeUserSetup-x64-1.109.5.exe

# %%
os.chdir(ruta)
print(os.getcwd())
# Out:
# c:\Users\oscar\Documents\DATASCIENCEOF\2026-02-BILBAO-FT-Data-Science\2-Data_Analysis\3-Sources\Archivos\Practica\Carpeta_backup_descargas

# %% [markdown]
# ### 2. Crea un programa standalone (main.py, funciones.py, variables.py) que realice la tarea sin necesidad de Jupyter notebooks.
