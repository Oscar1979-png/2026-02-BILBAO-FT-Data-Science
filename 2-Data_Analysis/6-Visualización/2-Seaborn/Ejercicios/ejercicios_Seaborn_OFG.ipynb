# %% [markdown]
# # Ejercicios de Seaborn

# %% [markdown]
# # 1. Importa pandas, pyplot y seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# # 3. Lee 'Pokemon.csv', lee la primera columna del csv como índice del DataFrame

# %%
df = pd.read_csv("./data/Pokemon.csv")
df.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     65      1      False
# 4     80      2      False

# %% [markdown]
# # 4. Mira las primeras filas del dataset para hacerte una idea de los datos cargados

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   #          151 non-null    int64
#  1   Name       151 non-null    str
#  2   Type 1     151 non-null    str
#  3   Type 2     67 non-null     str
#  4   Total      151 non-null    int64
#  5   HP         151 non-null    int64
#  6   Attack     151 non-null    int64
#  7   Defense    151 non-null    int64
#  8   Sp. Atk    151 non-null    int64
#  9   Sp. Def    151 non-null    int64
#  10  Speed      151 non-null    int64
#  11  Stage      151 non-null    int64
#  12  Legendary  151 non-null    bool
# dtypes: bool(1), int64(9), str(3)
# memory usage: 14.4 KB

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  151.000000  151.00000  151.000000  151.000000  151.000000  151.000000
# mean    76.000000  407.07947   64.211921   72.549669   68.225166   67.139073
# std     43.734045   99.74384   28.590117   26.596162   26.916704   28.534199
# min      1.000000  195.00000   10.000000    5.000000    5.000000   15.000000
# 25%     38.500000  320.00000   45.000000   51.000000   50.000000   45.000000
# 50%     76.000000  405.00000   60.000000   70.000000   65.000000   65.000000
# 75%    113.500000  490.00000   80.000000   90.000000   84.000000   87.500000
# max    151.000000  680.00000  250.000000  134.000000  180.000000  154.000000
#
#           Sp. Def       Speed       Stage
# count  151.000000  151.000000  151.000000
# mean    66.019868   68.933775    1.582781
# std     24.197926   26.746880    0.676832
# min     20.000000   15.000000    1.000000
# 25%     49.000000   46.500000    1.000000
# 50%     65.000000   70.000000    1.000000
# 75%     80.000000   90.000000    2.000000
# max    125.000000  140.000000    3.000000

# %% [markdown]
# # 5. Haz un scatter plot con lmplot(), que es el método que pinta una regresión lineal
# ### Pasa el DataFrame como argumento del método en el parámetro llamado data

# %%
sns.lmplot(data=df, x="Attack", y="Defense");

# %% [markdown]
# # 6. No queremos ver la línea recta de la regresión lineal.
# ### prueba a añadir fit_reg a falso

# %%
sns.lmplot(data=df, x="Attack", y="Defense", fit_reg=False)

# %% [markdown]
# # 7. Vamos a decir qué variable (columna del DataFrame) codifica los colores (hue)
# ### Que el hue sea el Stage

# %%
sns.lmplot(data=df, x="Attack", y="Defense", fit_reg=False, hue="Stage")

# %% [markdown]
# # 8. Limita el eje x entre 20 y 100

# %%
sns.lmplot(data=df, x="Attack", y="Defense", fit_reg=False, hue="Stage")
plt.xlim(20, 100)
# Out:
# (20.0, 100.0)

# %% [markdown]
# # 9. Dibuja un diagrama de cajas con el dataframe

# %%
sns.boxplot(x=df['Attack'])
# Out:
# <Axes: xlabel='Attack'>

# %% [markdown]
# # 10. No nos interesan las columnas Total, Stage ni Legendary
# ### Bórralos del DataFrame y vuelve a dibujar el diagrama de cajas

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   #          151 non-null    int64
#  1   Name       151 non-null    str
#  2   Type 1     151 non-null    str
#  3   Type 2     67 non-null     str
#  4   Total      151 non-null    int64
#  5   HP         151 non-null    int64
#  6   Attack     151 non-null    int64
#  7   Defense    151 non-null    int64
#  8   Sp. Atk    151 non-null    int64
#  9   Sp. Def    151 non-null    int64
#  10  Speed      151 non-null    int64
#  11  Stage      151 non-null    int64
#  12  Legendary  151 non-null    bool
# dtypes: bool(1), int64(9), str(3)
# memory usage: 14.4 KB

# %%
ej10= df.drop(['Total', 'Stage', 'Legendary'], axis=1)
ej10
# Out:
#        #        Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1   Bulbasaur    Grass  Poison   45      49       49       65       65
# 1      2     Ivysaur    Grass  Poison   60      62       63       80       80
# 2      3    Venusaur    Grass  Poison   80      82       83      100      100
# 3      4  Charmander     Fire     NaN   39      52       43       60       50
# 4      5  Charmeleon     Fire     NaN   58      64       58       80       65
# ..   ...         ...      ...     ...  ...     ...      ...      ...      ...
# 146  147     Dratini   Dragon     NaN   41      64       45       50       50
# 147  148   Dragonair   Dragon     NaN   61      84       65       70       70
# 148  149   Dragonite   Dragon  Flying   91     134       95      100      100
# 149  150      Mewtwo  Psychic     NaN  106     110       90      154       90
# 150  151         Mew  Psychic     NaN  100     100      100      100      100
#
#      Speed
# 0       45
# 1       60
# 2       80
# 3       65
# 4       80
# ..     ...
# 146     50
# 147     70
# 148     80
# 149    130
# 150    100
#
# [151 rows x 10 columns]

# %%
sns.boxplot(x=ej10['Attack'])
# Out:
# <Axes: xlabel='Attack'>

# %% [markdown]
# # 11. Mira cuántos 'Type 1' diferentes hay en el DataFrame

# %%
df['Type 1'].unique()
# Out:
# <StringArray>
# [   'Grass',     'Fire',    'Water',      'Bug',   'Normal',   'Poison',
#  'Electric',   'Ground',    'Fairy', 'Fighting',  'Psychic',     'Rock',
#     'Ghost',      'Ice',   'Dragon']
# Length: 15, dtype: str

# %%
df['Type 1'].nunique()
# Out:
# 15

# %% [markdown]
# # 12. Quédate del Dataframe solo con los 'Type 1' iguales a 'Grass', 'Fire' o 'Water'

# %%
df_ej12 = df[df['Type 1'].isin(['Grass', 'Fire', 'Water'])]
df_ej12
# Out:
#        #        Name Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur  Grass    Poison    318   45      49       49       65
# 1      2     Ivysaur  Grass    Poison    405   60      62       63       80
# 2      3    Venusaur  Grass    Poison    525   80      82       83      100
# 3      4  Charmander   Fire       NaN    309   39      52       43       60
# 4      5  Charmeleon   Fire       NaN    405   58      64       58       80
# 5      6   Charizard   Fire    Flying    534   78      84       78      109
# 6      7    Squirtle  Water       NaN    314   44      48       65       50
# 7      8   Wartortle  Water       NaN    405   59      63       80       65
# 8      9   Blastoise  Water       NaN    530   79      83      100       85
# 36    37      Vulpix   Fire       NaN    299   38      41       40       50
# 37    38   Ninetales   Fire       NaN    505   73      76       75       81
# 42    43      Oddish  Grass    Poison    320   45      50       55       75
# 43    44       Gloom  Grass    Poison    395   60      65       70       85
# 44    45   Vileplume  Grass    Poison    490   75      80       85      110
# 53    54     Psyduck  Water       NaN    320   50      52       48       65
# 54    55     Golduck  Water       NaN    500   80      82       78       95
# 57    58   Growlithe   Fire       NaN    350   55      70       45       70
# 58    59    Arcanine   Fire       NaN    555   90     110       80      100
# 59    60     Poliwag  Water       NaN    300   40      50       40       40
# 60    61   Poliwhirl  Water       NaN    385   65      65       65       50
# 61    62   Poliwrath  Water  Fighting    510   90      95       95       70
# 68    69  Bellsprout  Grass    Poison    300   50      75       35       70
# 69    70  Weepinbell  Grass    Poison    390   65      90       50       85
# 70    71  Victreebel  Grass    Poison    490   80     105       65      100
# 71    72   Tentacool  Water    Poison    335   40      40       35       50
# 72    73  Tentacruel  Water    Poison    515   80      70       65       80
# 76    77      Ponyta   Fire       NaN    410   50      85       55       65
# 77    78    Rapidash   Fire       NaN    500   65     100       70       80
# 78    79    Slowpoke  Water   Psychic    315   90      65       65       40
# 79    80     Slowbro  Water   Psychic    490   95      75      110      100
# 85    86        Seel  Water       NaN    325   65      45       55       45
# 86    87     Dewgong  Water       Ice    475   90      70       80       70
# 89    90    Shellder  Water       NaN    305   30      65      100       45
# 90    91    Cloyster  Water       Ice    525   50      95      180       85
# 97    98      Krabby  Water       NaN    325   30     105       90       25
# 98    99     Kingler  Water       NaN    475   55     130      115       50
# 101  102   Exeggcute  Grass   Psychic    325   60      40       80       60
# 102  103   Exeggutor  Grass   Psychic    520   95      95       85      125
# 113  114     Tangela  Grass       NaN    435   65      55      115      100
# 115  116      Horsea  Water       NaN    295   30      40       70       70
# 116  117      Seadra  Water       NaN    440   55      65       95       95
# 117  118     Goldeen  Water       NaN    320   45      67       60       35
# 118  119     Seaking  Water       NaN    450   80      92       65       65
# 119  120      Staryu  Water       NaN    340   30      45       55       70
# 120  121     Starmie  Water   Psychic    520   60      75       85      100
# 125  126      Magmar   Fire       NaN    495   65      95       57      100
# 128  129    Magikarp  Water       NaN    200   20      10       55       15
# 129  130    Gyarados  Water    Flying    540   95     125       79       60
# 130  131      Lapras  Water       Ice    535  130      85       80       85
# 133  134    Vaporeon  Water       NaN    525  130      65       60      110
# 135  136     Flareon   Fire       NaN    525   65     130       60       95
# 145  146     Moltres   Fire    Flying    580   90     100       90      125
#
#      Sp. Def  Speed  Stage  Legendary
# 0         65     45      1      False
# 1         80     60      2      False
# 2        100     80      3      False
# 3         50     65      1      False
# 4         65     80      2      False
# 5         85    100      3      False
# 6         64     43      1      False
# 7         80     58      2      False
# 8        105     78      3      False
# 36        65     65      1      False
# 37       100    100      2      False
# 42        65     30      1      False
# 43        75     40      2      False
# 44        90     50      3      False
# 53        50     55      1      False
# 54        80     85      2      False
# 57        50     60      1      False
# 58        80     95      2      False
# 59        40     90      1      False
# 60        50     90      2      False
# 61        90     70      3      False
# 68        30     40      1      False
# 69        45     55      2      False
# 70        70     70      3      False
# 71       100     70      1      False
# 72       120    100      2      False
# 76        65     90      1      False
# 77        80    105      2      False
# 78        40     15      1      False
# 79        80     30      2      False
# 85        70     45      1      False
# 86        95     70      2      False
# 89        25     40      1      False
# 90        45     70      2      False
# 97        25     50      1      False
# 98        50     75      2      False
# 101       45     40      1      False
# 102       65     55      2      False
# 113       40     60      1      False
# 115       25     60      1      False
# 116       45     85      2      False
# 117       50     63      1      False
# 118       80     68      2      False
# 119       55     85      1      False
# 120       85    115      2      False
# 125       85     93      1      False
# 128       20     80      1      False
# 129      100     81      2      False
# 130       95     60      1      False
# 133       95     65      2      False
# 135      110     65      2      False
# 145       85     90      1       True

# %% [markdown]
# # 13. Usa un estilo 'whitegrid'

# %%
sns.set_style("whitegrid")

# %% [markdown]
# # 14. Pinta diagramas de violín con el DataFrame filtrado por los 3 tipos

# %%
plt.figure(figsize=(20,5))
sns.violinplot(x='Type 1', y="Attack", data=ej10, color='lightseagreen', bw=.5, inner="stick");
# Out:
# C:\Users\oscar\AppData\Local\Temp\ipykernel_18484\1490766821.py:2: FutureWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method`/`bw_adjust`.
# Setting `bw_method=0.5`, but please see docs for the new parameters
# and update your code. This will become an error in seaborn v0.15.0.
#
#   sns.violinplot(x='Type 1', y="Attack", data=ej10, color='lightseagreen', bw=.5, inner="stick");

# %% [markdown]
# # 15. Escribe una lista de colores con valores '#78C850', '#F08030',  '#6890F0'

# %%
lista_colores = ['#78C850', '#F08030',  '#6890F0']

# %% [markdown]
# # 16. Pinta de nuevo los diagramas de violín añadiendo esos colores en la paleta (palette)

# %%
sns.violinplot(x="Type 1", y="Attack", data=df_ej12, palette=lista_colores)
# Out:
# C:\Users\oscar\AppData\Local\Temp\ipykernel_18484\2772883404.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="Type 1", y="Attack", data=df_ej12, palette=lista_colores)
# <Axes: xlabel='Type 1', ylabel='Attack'>

# %%
sns.lmplot(data=df, x="Attack", y="Defense", fit_reg=False, hue="Stage")

# %% [markdown]
# # 17. Con el diagrama de violín vemos la forma de la distribución, pero no sabemos si Grass tiene muchos puntos y Fire tiene muy pocos.
# ### Para ver esto, usamos el swarmplot.
# ### Pinta el último diagrama de violines pero con un swarmplot en lugar de un violin

# %%
sns.swarmplot(x='Type 1', y="Attack", data=ej10);

# %% [markdown]
# # 18. Queremos ver los violines a la vez que los swarm, los podemos pintar juntos.
# ### Elimina los diagramas de caja dentro de los violines con el parámetro inner = None y pon una transparencia de 0.9 en el swarmplot
# ### Pon un título con pyplot (como siempre)

# %%
sns.violinplot(x="Type 1", y="Attack", data=df_ej12, palette=lista_colores, inner=None)      ##inner none elimina el paramentor 
sns.swarmplot(x="Type 1", y="Attack", data=df_ej12, color="k", alpha=0.9);       ##alpha, transparencia
plt.ylim(-20, 180)
plt.title("Distribución ataque planta, fuego, agua");
# Out:
# C:\Users\oscar\AppData\Local\Temp\ipykernel_18484\583745894.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="Type 1", y="Attack", data=df_ej12, palette=lista_colores, inner=None)      ##inner none elimina el paramentor

# %% [markdown]
# # 19. Veamos la función melt() de pandas. Melt toma los valores de varias columnas y los junta todos en una misma columna nueva.
# ### Dado un DataFrame, melt recibe varios parámetros:
# ### * qué columnas del DataFrame se quedan igual
# ### * qué nombres de columnas del dataframe pasan a ser una columna nueva
# ### * cómo queremos llamar esas nuevas columnas
#
# ### Primero recuerda el Dataframe df_grass_fire_water con las primeras 5 filas

# %%
df_ej12.head(5)
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     65      1      False
# 4     80      2      False

# %%
df_ej12 = df_ej12.melt(id_vars=['New'], var_name='Attack', value_name='Speed')
print(df_ej12)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df_ej12 = df_ej12.melt(id_vars=['New'], var_name='Attack', value_name='Speed')
#       2 print(df_ej12)
#
# File c:\Users\oscar\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11697, in DataFrame.melt(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#   11567 def melt(
#   11568     self,
#   11569     id_vars=None,
#    (...)  11574     ignore_index: bool = True,
#   11575 ) -> DataFrame:
#   11576     """
#   11577     Unpivot DataFrame from wide to long format, optionally leaving identifiers set.
#   11578
#    (...)  11695     2      c          B          E      5
#   11696     """
# > 11697     return melt(
#   11698         self,
#   11699         id_vars=id_vars,
#   11700         value_vars=value_vars,
#   11701         var_name=var_name,
#   11702         value_name=value_name,
#   11703         col_level=col_level,
#   11704         ignore_index=ignore_index,
#   11705     ).__finalize__(self, method="melt")
#
# File c:\Users\oscar\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\melt.py:180, in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#      54 """
#      55 Unpivot a DataFrame from wide to long format, optionally leaving identifiers set.
#      56
#    (...)    177 2      c          B          E      5
#     178 """
#     179 if value_name in frame.columns:
# --> 180     raise ValueError(
#     181         f"value_name ({value_name}) cannot match an element in "
#     182         "the DataFrame columns."
#     183     )
#     184 id_vars = ensure_list_vars(id_vars, "id_vars", frame.columns)
#     185 value_vars_was_not_none = value_vars is not None
#
# ValueError: value_name (Speed) cannot match an element in the DataFrame columns.

# %% [markdown]
# # 20. Queremos dejar igual las variables 'Name' y 'Type 1'
# ### Queremos añadir una columa nueva cuyos valores sean las columnas que queremos apilar y que se llame 'New Column'
# ### Escribimos df_gfw.melt(id_vars=['Name', 'Type 1'], value_vars=[...], var_name='New Column')

# %%
df_melted = df_ej12.melt(id_vars=["Name", "Type 1"], value_vars=df_ej12.columns[4:10], var_name="New Column") 
df_melted.sort_values("Name")
# Out:
#            Name Type 1 New Column  value
# 225    Arcanine   Fire    Sp. Atk    100
# 277    Arcanine   Fire    Sp. Def     80
# 17     Arcanine   Fire      Total    555
# 69     Arcanine   Fire         HP     90
# 121    Arcanine   Fire     Attack    110
# ..          ...    ...        ...    ...
# 178  Weepinbell  Grass    Defense     50
# 126  Weepinbell  Grass     Attack     90
# 230  Weepinbell  Grass    Sp. Atk     85
# 74   Weepinbell  Grass         HP     65
# 282  Weepinbell  Grass    Sp. Def     45
#
# [312 rows x 4 columns]

# %% [markdown]
# # 21. Pintamos el swarmplot con el melted y entendemos la información

# %%
sns.swarmplot(x="Type 1", y='value', data=df_melted, hue="Type 1");
# Out:
# c:\Users\oscar\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 5.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\oscar\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 19.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # 22. Basándote en el gráfico anterior, define el tamaño de la figura en (10,6) (usa plt)
# ### En el swarmplot añade el argumento dodge a True y usa la anterior paleta de colores Pokemon
#
# ### Dodge en inglés es "esquivar", ¿qué diferencia ves?
#
# ## Usando plt
# ### fija el límite del eje Y entre 0 y 200
# ### fija la leyenda con bbox_to_anchor en upper left. Pista: upper left es el código 2 y se usa el parámetro loc.

# %% [markdown]
# ### Observa que incluso usando Seaborn, usamos Pyplot para trabajar con los ejes, la leyenda y el tamaño
# ### Lo importante es que Seaborn y Pyplot conviven bien juntos

# %%
plt.figure(figsize=(10,6))
sns.swarmplot(x="Type 1", y='value', data=df_melted, hue="Type 1", palette=lista_colores, dodge=True);
plt.ylim(0,200)
plt.legend(bbox_to_anchor=(0.15, 1))
# Out:
# C:\Users\oscar\AppData\Local\Temp\ipykernel_18484\429557629.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(bbox_to_anchor=(0.15, 1))

# %% [markdown]
# # 23. Mapas de calor
# ### Calcula las correlaciones del primer DataFrame original df
# ### Pista: las correlaciones se calculan con el método corr()
# ### Recuerda: las correlaciones miden entre dos variables, si varío una, cuánto me varía la otra (cómo están de relacionadas)

# %%
df.corr(numeric_only=True)
# Out:
#                   #     Total        HP    Attack   Defense   Sp. Atk  \
# #          1.000000  0.386403  0.204389  0.260973  0.325882  0.255471
# Total      0.386403  1.000000  0.576591  0.670939  0.508694  0.680745
# HP         0.204389  0.576591  1.000000  0.306768  0.119782  0.236649
# Attack     0.260973  0.670939  0.306768  1.000000  0.491965  0.146312
# Defense    0.325882  0.508694  0.119782  0.491965  1.000000  0.187569
# Sp. Atk    0.255471  0.680745  0.236649  0.146312  0.187569  1.000000
# Sp. Def    0.254515  0.774383  0.490978  0.369069  0.139912  0.522907
# Speed      0.132233  0.506950 -0.040939  0.194701 -0.053252  0.411516
# Stage     -0.274544  0.504224  0.249207  0.361321  0.270861  0.391712
# Legendary  0.265853  0.328412  0.172441  0.147486  0.141576  0.334159
#
#             Sp. Def     Speed     Stage  Legendary
# #          0.254515  0.132233 -0.274544   0.265853
# Total      0.774383  0.506950  0.504224   0.328412
# HP         0.490978 -0.040939  0.249207   0.172441
# Attack     0.369069  0.194701  0.361321   0.147486
# Defense    0.139912 -0.053252  0.270861   0.141576
# Sp. Atk    0.522907  0.411516  0.391712   0.334159
# Sp. Def    1.000000  0.392656  0.358308   0.215314
# Speed      0.392656  1.000000  0.240042   0.199969
# Stage      0.358308  0.240042  1.000000  -0.142508
# Legendary  0.215314  0.199969 -0.142508   1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), vmin=-1, vmax=1, annot=True, cmap="Spectral")
# Out:
# <Axes: >

# %% [markdown]
# ### ¿la correlación entre qué valores se encuentra?
# ### la autocorrelación es la correlación de una variable consigo misma, ¿qué aprecias?
# ### Encuentra dos variables que veas que están fuertemente relacionadas según la correlación

# %%
df.corr(numeric_only=True).min()
# Out:
# #           -0.274544
# Total        0.328412
# HP          -0.040939
# Attack       0.146312
# Defense     -0.053252
# Sp. Atk      0.146312
# Sp. Def      0.139912
# Speed       -0.053252
# Stage       -0.274544
# Legendary   -0.142508
# dtype: float64

# %% [markdown]
# [-0.14, 1]
# Es de 1 porque aumentan exactamente lo mismo
# Total y Sp. Defense que tienne correlación positiva, cuyo coeficiente de corr de Person es de 0.77
# Buscaría en ML, las variables que mayor correladas estén con la variable a predecir, por lo tanto podríamos aproximar en hacer un filtro de variables basado en este criterio, y por tanto una reducción de recursos

# %% [markdown]
# # 24. Pinta el histograma y la densidad de probabilidad del nivel de defensa usando el DataFrame original

# %%
sns.displot(df['Defense'], kde=True)

# %% [markdown]
# # 25. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original
# ### Usa un sns.countplot
# ### Usa plt.xticks y gira las etiquetas

# %%
sns.countplot(x="Type 1", data=df, order = df["Type 1"].value_counts().index)
plt.xticks(rotation=-45);

# %% [markdown]
# # 26. Usa catplot con el DataFrame original.
# ### Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendarios y divide los colores según el Type 2

# %%
chart = sns.catplot(x="Type 1", y="Defense", data=df, hue="Type 2", col="Legendary")
chart.set_xticklabels(rotation=-45);

# %% [markdown]
# # 27. Muestra una función distribución de probabilidad con kdeplot (curvas de nivel) de la defensa respecto al ataque.
# ### Di un bin 2D donde caigan muchos puntos (ataque, defensa).

# %%
sns.kdeplot(x=df['Attack'], y=df['Defense'])
# Out:
# <Axes: xlabel='Attack', ylabel='Defense'>

# %% [markdown]
# # 28. Pinta una distribución de probabilidad conjunta con jointplot, pintando la defensa respecto al ataque del DataFrame original

# %%
sns.jointplot(x=df['Attack'], y=df['Defense'], kind="kde")
