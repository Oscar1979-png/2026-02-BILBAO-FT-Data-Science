# %% [markdown]
# ## Juego del Ahorcado
# El funcionamiento es que vaya mostrando por pantalla ```_ _ _ _ _``` las rayas bajas correspondientes al número de letras que tiene la palabra a adivinar. El usuario deberá insertar una letra y, si esa letra existe, se mostrará o mostrarán las letras acertadas ```S _ S _ _```.
#
# Si falla, se mostrará el número de errores que lleva y, si lleva 6 errores, entonces se mostrará "Fin del juego".
# Encapsúlalo en una función.

# %%
import random

# %%
lista_palabras = ["Bootcamp", "RampUp"]
palabra_elegida = random.choice(lista_palabras)
palabra_elegida = palabra_elegida.upper()
print(palabra_elegida)
# Out:
# RAMPUP

# %%
palabra_oculta = "_" * len(palabra_elegida)
palabra_oculta = list(palabra_oculta)
print(*palabra_oculta)          #desempaqueta la lista
# Out:
# _ _ _ _ _ _

# %%
vidas = 6
letra_usuario = input("Introduce una letra: ")
letra_usuario = letra_usuario.upper()
print(letra_usuario)
# Out:
# A

# %%
import random
import time

lista_palabras = ["Bootcamp", "RampUp"]
palabra_elegida = random.choice(lista_palabras)
palabra_elegida = palabra_elegida.upper()

palabra_oculta = "_" * len(palabra_elegida)
palabra_oculta = list(palabra_oculta)

vidas = 6

while vidas > 0:
    time.sleep(1)
    letra_usuario = input("Introduce una letra: ")
    letra_usuario = letra_usuario.upper()

    if letra_usuario in palabra_elegida:
        for i in range(len(palabra_elegida)):
            if palabra_elegida[i] == letra_usuario:
                palabra_oculta[i] = letra_usuario
        
        if "_" not in palabra_oculta:           #si no quedan guiones...
            print("Has ganado!")
            print(*palabra_oculta)
            break

        print("Has acertado!")
        print(*palabra_oculta)

    else:
        vidas -= 1
        print("Has fallado!")
        print(f'Vidas:{vidas}')
        print(*palabra_oculta)


        if vidas == 0:
            print("Has perdido :(")
# Out:
# Has acertado!
# B _ _ _ _ _ _ _
# Has acertado!
# B O O _ _ _ _ _
# Has acertado!
# B O O T _ _ _ _
# Has acertado!
# B O O T C _ _ _
# Has acertado!
# B O O T C A _ _
# Has acertado!
# B O O T C A M _
# Has ganado!
# B O O T C A M P

# %%
def ahorcado(lista_palabras, vidas):

    palabra_elegida = random.choice(lista_palabras)
    palabra_elegida = palabra_elegida.upper()

    palabra_oculta = "_" * len(palabra_elegida)
    palabra_oculta = list(palabra_oculta)


    while vidas > 0:
        time.sleep(1)
        letra_usuario = input("Introduce una letra: ")
        letra_usuario = letra_usuario.upper()

        if letra_usuario in palabra_elegida:
            for i in range(len(palabra_elegida)):
                if palabra_elegida[i] == letra_usuario:
                    palabra_oculta[i] = letra_usuario
            
            if "_" not in palabra_oculta:
                print("Has ganado!")
                print(*palabra_oculta)
                break

            print("Has acertado!")
            print(*palabra_oculta)

        else:
            vidas -= 1
            print("Has fallado!")
            print(f'Vidas:{vidas}')
            print(*palabra_oculta)


            if vidas == 0:
                print("Has perdido :(")

# %%
ahorcado(["Hola", "Adios"], 3)      #en script se ejecuta el main. Y carpetas por secciones. Te abres una terminal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 ahorcado(["Hola", "Adios"], 3)      #en script se ejecuta el main
#
# NameError: name 'ahorcado' is not defined
