# %% [markdown]
# A typical digital image is made by stacking Red, Blue and Green pixel arrays of intensities ranging from 0 to 255.

# %% [markdown]
# <img src="./img/RGB.PNG">

# %% [markdown]
# A grayscale image does not contain color but only shades of gray. The pixel intensity in a grayscale image varies from black (0 intensity) to white (255 full intensity) to make it what we usually call as a Black & White image.

# %% [markdown]
# Digits dataset is a grayscale image dataset of handwritten digit having 1797 8×8 images.

# %%
#importing the dataset
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
 
digits = load_digits()
data = digits.data
data.shape
# Out:
# (1797, 64)

# %%
data[0].reshape(8, 8)
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %% [markdown]
# sklearn.datasets module makes it quick to import digits data by importing load_digits class from it. The shape of the digit data is (1797, 64). 8×8 pixels are flattened to create a vector of length 64 for every image.

# %%
#taking a sample image to view
#Remember image is in the form of numpy array.
image_sample = data[0,:].reshape(8,8)
image_sample
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
digits.data.shape
# Out:
# (1797, 64)

# %%
plt.imshow(image_sample, cmap='binary')

# %% [markdown]
# Now, using PCA, let’s reduce the image dimensions from 64 to just 2 so that we can visualize the dataset using a Scatterplot.

# %%
from sklearn.decomposition import PCA

pca = PCA(2)
converted_data = pca.fit_transform(digits.data)

converted_data.shape
# Out:
# (1797, 2)

# %% [markdown]
# We can also pass a float value less than 1 instead of an integer number. i.e. PCA(0.90) this means the algorithm will find the principal components which explain 90% of the variance in data.

# %%
#plt.style.use('seaborn-whitegrid')
plt.figure(figsize = (10,6))
c_map = plt.cm.get_cmap('jet', 10)
plt.scatter(converted_data[:, 0], converted_data[:, 1], s = 15,
            cmap = c_map , c = digits.target)
plt.colorbar()
plt.xlabel('PC-1') , plt.ylabel('PC-2')
plt.show();         ## de 64 pixels, ahora sacamos solo 2 combinaciones
# Out:
# C:\Users\oscar\AppData\Local\Temp\ipykernel_21824\4166187254.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   c_map = plt.cm.get_cmap('jet', 10)

# %% [markdown]
# Another cool application of PCA is in Image compression. Let’s have a look at how can we achieve this with python.

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=2 in c:\users\oscar\appdata\local\programs\python\python311\lib\site-packages (from opencv-python) (2.3.5)
# Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    ---------------------------------------- 0.1/40.2 MB 1.1 MB/s eta 0:00:36
#    ---------------------------------------- 0.4/40.2 MB 3.7 MB/s eta 0:00:11
#    - -------------------------------------- 1.5/40.2 MB 9.6 MB/s eta 0:00:05
#    -- ------------------------------------- 2.9/40.2 MB 14.1 MB/s eta 0:00:03
#    ---- ----------------------------------- 4.2/40.2 MB 16.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.5/40.2 MB 18.5 MB/s eta 0:00:02
#    ------ --------------------------------- 6.8/40.2 MB 19.7 MB/s eta 0:00:02
#    -------- ------------------------------- 8.1/40.2 MB 20.7 MB/s eta 0:00:02
#    --------- ------------------------------ 9.6/40.2 MB 21.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 10.9/40.2 MB 28.4 MB/s eta 0:00:02
#    ------------ --------------------------- 12.3/40.2 MB 29.8 MB/s eta 0:00:01
#    ------------ --------------------------- 12.9/40.2 MB 28.4 MB/s eta 0:00:01
#    -------------- ------------------------- 14.1/40.2 MB 26.2 MB/s eta 0:00:01
#    -------------- ------------------------- 14.6/40.2 MB 26.2 MB/s eta 0:00:01
#    --------------- ------------------------ 15.5/40.2 MB 23.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 16.7/40.2 MB 23.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 17.9/40.2 MB 23.4 MB/s eta 0:00:01
#    ------------------ --------------------- 18.8/40.2 MB 23.4 MB/s eta 0:00:01
#    ------------------ --------------------- 18.9/40.2 MB 21.1 MB/s eta 0:00:02
#    -------------------- ------------------- 20.7/40.2 MB 21.1 MB/s eta 0:00:01
#    --------------------- ------------------ 21.3/40.2 MB 21.8 MB/s eta 0:00:01
#    --------------------- ------------------ 22.0/40.2 MB 18.7 MB/s eta 0:00:01
#    ------------------------ --------------- 24.3/40.2 MB 21.8 MB/s eta 0:00:01
#    ------------------------- -------------- 25.7/40.2 MB 24.2 MB/s eta 0:00:01
#    -------------------------- ------------- 27.1/40.2 MB 25.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 28.6/40.2 MB 25.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 29.8/40.2 MB 28.5 MB/s eta 0:00:01
#    ------------------------------ --------- 30.6/40.2 MB 27.3 MB/s eta 0:00:01
#    ------------------------------- -------- 31.4/40.2 MB 25.2 MB/s eta 0:00:01
#    -------------------------------- ------- 32.7/40.2 MB 27.3 MB/s eta 0:00:01
#    --------------------------------- ------ 33.3/40.2 MB 25.2 MB/s eta 0:00:01
#    --------------------------------- ------ 34.1/40.2 MB 22.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 34.7/40.2 MB 24.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 35.6/40.2 MB 21.1 MB/s eta 0:00:01
#    ------------------------------------ --- 36.7/40.2 MB 21.8 MB/s eta 0:00:01
#    ------------------------------------- -- 37.6/40.2 MB 20.5 MB/s eta 0:00:01
#    -------------------------------------- - 38.7/40.2 MB 20.5 MB/s eta 0:00:01
#    ---------------------------------------  39.6/40.2 MB 19.9 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 19.2 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 19.2 MB/s eta 0:00:01
#    ---------------------------------------  40.2/40.2 MB 19.2 MB/s eta 0:00:01
#    ---------------------------------------- 40.2/40.2 MB 15.6 MB/s eta 0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.13.0.92
# [notice] A new release of pip is available: 24.0 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Importing required libraries
import cv2
import numpy as np
from sklearn.decomposition import PCA

# %%
# Loading the image 
img = cv2.imread('img/my_doggo_sample.jpeg')

# %%
img.shape           ## 3 colores
# Out:
# (793, 1280, 3)

# %%
793*1280*3      ## esa imagen tiene 3 millones de valores
# Out:
# 3045120

# %%
img[0].shape
# Out:
# (1280, 3)

# %%
img
# Out:
# array([[[133, 163, 183],
#         [133, 163, 183],
#         [133, 163, 183],
#         ...,
#         [192, 216, 246],
#         [193, 217, 248],
#         [193, 217, 248]],
#
#        [[133, 163, 183],
#         [133, 163, 183],
#         [133, 163, 183],
#         ...,
#         [191, 215, 245],
#         [192, 216, 246],
#         [192, 216, 246]],
#
#        [[133, 163, 183],
#         [133, 163, 183],
#         [133, 163, 183],
#         ...,
#         [189, 213, 243],
#         [190, 214, 244],
#         [190, 214, 244]],
#
#        ...,
#
#        [[ 47,  63,  76],
#         [ 30,  45,  56],
#         [ 47,  63,  69],
#         ...,
#         [ 26,  51,  77],
#         [ 29,  55,  79],
#         [ 50,  76, 100]],
#
#        [[ 46,  62,  75],
#         [ 18,  35,  46],
#         [ 29,  45,  52],
#         ...,
#         [ 40,  67,  95],
#         [ 40,  68,  93],
#         [ 48,  77, 100]],
#
#        [[ 32,  48,  61],
#         [ 17,  34,  45],
#         [ 20,  36,  42],
#         ...,
#         [ 47,  74, 102],
#         [ 43,  73,  98],
#         [ 48,  79, 103]]], shape=(793, 1280, 3), dtype=uint8)

# %%
plt.imshow(img);            ## aqui estan cambiados los canales del color BGR

# %%
rgb_image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)    ## blue green red
plt.imshow(rgb_image);

# %%
img.shape
# Out:
# (793, 1280, 3)

# %%
img.size
# Out:
# 3045120

# %%
793*1280
# Out:
# 1015040

# %%
img
# Out:
# array([[[133, 163, 183],
#         [133, 163, 183],
#         [133, 163, 183],
#         ...,
#         [192, 216, 246],
#         [193, 217, 248],
#         [193, 217, 248]],
#
#        [[133, 163, 183],
#         [133, 163, 183],
#         [133, 163, 183],
#         ...,
#         [191, 215, 245],
#         [192, 216, 246],
#         [192, 216, 246]],
#
#        [[133, 163, 183],
#         [133, 163, 183],
#         [133, 163, 183],
#         ...,
#         [189, 213, 243],
#         [190, 214, 244],
#         [190, 214, 244]],
#
#        ...,
#
#        [[ 47,  63,  76],
#         [ 30,  45,  56],
#         [ 47,  63,  69],
#         ...,
#         [ 26,  51,  77],
#         [ 29,  55,  79],
#         [ 50,  76, 100]],
#
#        [[ 46,  62,  75],
#         [ 18,  35,  46],
#         [ 29,  45,  52],
#         ...,
#         [ 40,  67,  95],
#         [ 40,  68,  93],
#         [ 48,  77, 100]],
#
#        [[ 32,  48,  61],
#         [ 17,  34,  45],
#         [ 20,  36,  42],
#         ...,
#         [ 47,  74, 102],
#         [ 43,  73,  98],
#         [ 48,  79, 103]]], shape=(793, 1280, 3), dtype=uint8)

# %%
# Splitting the image in R,G,B arrays.
blue, green, red = cv2.split(img)           ## guarda por separado

#it will split the original image into Blue, Green and Red arrays.

# %%
blue.shape
# Out:
# (793, 1280)

# %%
793*1280
# Out:
# 1015040

# %%
img_not_compressed = cv2.merge([red,green,blue])    ## al juntar los colores se recupera la imagen original
#viewing the not compressed image
plt.imshow(img_not_compressed);

# %%
img_not_compressed = cv2.merge([blue, green, red])
#viewing the not compressed image
plt.imshow(img_not_compressed);

# %% [markdown]
# OpenCV will split into Blue, Green, and Red channels instead of Red, Blue, and Green. Be very careful of the sequence here.

# %%
# Initialize PCA with first 20 principal components
pca = PCA(20)
 
#Applying to red channel and then applying inverse transform to transformed array.
red_transformed = pca.fit_transform(red)
print('red_transformed.shape:', red_transformed.shape)
red_inverted = pca.inverse_transform(red_transformed)
print('red_inverted.shape:', red_inverted.shape)

#Applying to Green channel and then applying inverse transform to transformed array.
green_transformed = pca.fit_transform(green)
print('green_transformed.shape:', green_transformed.shape)
green_inverted = pca.inverse_transform(green_transformed)
print('green_inverted.shape:', green_inverted.shape)
 
#Applying to Blue channel and then applying inverse transform to transformed array.
blue_transformed = pca.fit_transform(blue)
print('blue_transformed.shape:', blue_transformed.shape)
blue_inverted = pca.inverse_transform(blue_transformed)
print('blue_inverted.shape:', blue_inverted.shape)
# Out:
# red_transformed.shape: (793, 20)
# red_inverted.shape: (793, 1280)
# green_transformed.shape: (793, 20)
# green_inverted.shape: (793, 1280)
# blue_transformed.shape: (793, 20)
# blue_inverted.shape: (793, 1280)

# %%
1280/20         ## de 1280 se pasa a 20 pixels, compresion de la imagen pero con perdida de informacion...
# Out:
# 64.0

# %% [markdown]
# In the process of reconstructing the original dimensions from the reduced dimensions, some information is lost as we keep only selected principal components, 20 in this case.

# %%
img_compressed = (cv2.merge([red_inverted, green_inverted, blue_inverted])).astype(np.uint8)

# %% [markdown]
# Stacking the inverted arrays using dstack function. Here it is important to specify the datatype of our arrays, as most images are of 8 bit. Each pixel is represented by one 8-bit byte.

# %%
#viewing the compressed image
plt.imshow(img_compressed)
# plt.imsave('img\img_compressed.jpg', img_compressed);

# %% [markdown]
# The output above is what we get when considering just 20 Principal components. (Nota: lo hemos aplicado al largo, no a toda la imagen con reshape. Aún así la compresión ha sido muy alta: de 1280 a 20)
#
# If we increase the number of Principal components the output image will get clear.

# %%
# Initialize PCA with first 20 principal components
pca = PCA(200)          ## de 1280 a 200 pixels. JPEG hace esa reduccion habitualmente
 
#Applying to red channel and then applying inverse transform to transformed array.
red_transformed = pca.fit_transform(red)
print('red_transformed.shape:', red_transformed.shape)
red_inverted = pca.inverse_transform(red_transformed)
print('red_inverted.shape:', red_inverted.shape)

#Applying to Green channel and then applying inverse transform to transformed array.
green_transformed = pca.fit_transform(green)
print('green_transformed.shape:', green_transformed.shape)
green_inverted = pca.inverse_transform(green_transformed)
print('green_inverted.shape:', green_inverted.shape)
 
#Applying to Blue channel and then applying inverse transform to transformed array.
blue_transformed = pca.fit_transform(blue)
print('blue_transformed.shape:', blue_transformed.shape)
blue_inverted = pca.inverse_transform(blue_transformed)
print('blue_inverted.shape:', blue_inverted.shape)

img_compressed = (cv2.merge([red_inverted, green_inverted, blue_inverted])).astype(np.uint8)

#viewing the compressed image
plt.imshow(img_compressed);

## se comprime manteniendo la calidad
# Out:
# red_transformed.shape: (793, 200)
# red_inverted.shape: (793, 1280)
# green_transformed.shape: (793, 200)
# green_inverted.shape: (793, 1280)
# blue_transformed.shape: (793, 200)
# blue_inverted.shape: (793, 1280)

# %%
img_compressed = (cv2.merge([red_transformed, green_transformed, blue_transformed])).astype(np.uint8)

#viewing the compressed image
plt.imshow(img_compressed);         ## sin hacer la descompresion... no se ve la imagen

# %%
img_compressed.shape
# Out:
# (793, 200, 3)

# %%
pca.explained_variance_ratio_.cumsum()
# Out:
# array([0