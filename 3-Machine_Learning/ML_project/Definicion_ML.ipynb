# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo =

# %% [markdown]
# "Análisis ML de escala SMAQ-10 con diferentes técnicas supervisadas"

# %% [markdown]
# ### TEMA

# %%
# Describe brevemente el tema del proyecto en Markdown
tema =

# %% [markdown]
#  Comparar los resultados de las diferentes técnicas supervisadas en el análisis de los resultados del estudio de la escala SMAQ-10.

# %% [markdown]
# ### OBJETIVOS

# %% [markdown]
# Define aquí el objetivo del proyecto

# %% [markdown]
# El objetivo es hacer un estudio de los resultados de las diferentes técnicas supervisadas en el análisis de los resultados del análisis de la escala SMAQ-10 con ML:
#
# 1. Linear Regression
# 2. Regularization
# 3. Logistic regression
# 5. Decision trees
# 6. Ensembles
# 7. KNN
# 8. SVM

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %% [markdown]
# Este dataset viene de:
# Social Media Addiction SMA10 Dataset
# Published: 6 January 2025, Version 1
#
# DOI: 10.17632/9mxm455dfm.1
#
# Contributors:
# Md. Mukhlesur Rahman, Golam Rabbany, Biplob7991 Biplob Hossain, ABM Alauddin Chowdhury
#
# https://data.mendeley.com/datasets/9mxm455dfm/1

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset
# df_1.head()

# %%
# Siguiente dataset...
# df_2.head()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("SMA.csv")
df.head()
# Out:
#    Q1_Gender  Q2_Living_Area  Q3_Maritial_Status  SMAQ1  SMAQ2  SMAQ3  SMAQ4  \
# 0          1               1                   2      4      5      1      3
# 1          1               1                   2      3      2      1      5
# 2          2               1                   2      3      2      1      1
# 3          1               2                   2      2      5      5      2
# 4          1               1                   2      1      4      3      1
#
#    SMAQ5  SMAQ6  SMAQ7  SMAQ8  SMAQ9  SMAQ10  SMA_Scale_value  \
# 0      5      2      2      4      5       3               34
# 1      5      1      1      2      5       1               26
# 2      1      1      1      1      1       1               13
# 3      3      1      3      4      4       1               30
# 4      2      1      1      1      1       1               16
#
#    SMA_Scale (Class_Lebel)
# 0                        2
# 1                        2
# 2                        1
# ...
